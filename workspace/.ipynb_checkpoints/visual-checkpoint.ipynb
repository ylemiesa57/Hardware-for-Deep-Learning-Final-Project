# %% [markdown]
# ### Part 0: starting up workload

# %%
print("HI")
# Out:
# HI

# %%
# from loaders import answer, AnswerMe
from numbers import Number
from typing import List
import matplotlib.pyplot as plt
from IPython.display import display, Math
import accelforge as af
from accelforge.mapper import Metrics
import matplotlib.pyplot as plt

# with open("./specs/fc.workload.yaml") as f:
# 	print(f.read())

# %%
spec = af.spec.Spec.from_yaml(
	"./specs/fc.workload.yaml"
)
spec.workload
# Out:
# Workload(einsums=[Einsum(name='Fc', tensor_accesses=[TensorAccess(name='I', projection={'M': 'm', 'K': 'k'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=8), TensorAccess(name='F', projection={'K': 'k', 'N': 'n'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=8), TensorAccess(name='O', projection={'M': 'm', 'N': 'n'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=8)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1)], iteration_space_shape={}, rank_sizes={'M': 128, 'N': 128, 'K': 128}, n_instances=1, bits_per_value={}, persistent_tensors=None)

# %%
with open("./specs/simple.arch.yaml") as f:
	print(f.read())
# Out:
# arch:
#   nodes:
#   - !Memory
#     name: DRAM
#     component_class: LPDDR4
#     size: inf
#     total_latency: (read_actions + write_actions)/(200e9)  # equivalent to 200 Gb/s bandwidth
#     tensors:
#       keep: All
#     extra_attributes_for_component_model:
#       width: 64
#
#   - !Memory
#     name: OnchipBuffer
#     size: 1024*1024 # size in bits
#     total_latency: (read_actions + write_actions)/64e12  # equivalent to 64 Tb/s bandwidth
#     area: 0  # we are not modeling area
#     leak_power: 0 # we are not modeling leakage
#     tensors:
#       keep: All
#     actions:
#     - name: read
#       energy: 5
#       latency: 0
#     - name: write
#       energy: 5
#       latency: 0
#
#   - !Compute
#     name: MAC
#     area: 0  # we are not modeling area
#     leak_power: 0 # we are not modeling leakage
#     spatial:
#     - name: ComputeArrayX
#       fanout: 32
#       loop_bounds:
#       - expression: c
#         operator: ==
#         value: 32
#       - expression: m
#         operator: ==
#         value: 1
#       - expression: p
#         operator: ==
#         value: 1
#       - expression: q
#         operator: ==
#         value: 1
#       - expression: n
#         operator: ==
#         value: 1
#       - expression: r
#         operator: ==
#         value: 1
#       - expression: s
#         operator: ==
#         value: 1
#     - name: ComputeArrayY
#       fanout: 256
#       loop_bounds:
#       - expression: c
#         operator: ==
#         value: 1
#       - expression: m
#         operator: ==
#         value: 128
#       - expression: p
#         operator: ==
#         value: 1
#       - expression: q
#         operator: ==
#         value: 1
#       - expression: r
#         operator: ==
#         value: 1
#       - expression: s
#         operator: ==
#         value: 1
#     actions:
#     - name: compute
#       energy: 1
#       latency: 1e-9

# %%
spec = af.Spec.from_yaml(
    "./specs/conv.workload.yaml",
    jinja_parse_data={"N": 1}
)
spec.workload
# Out:
# Workload(einsums=[Einsum(name='Conv', tensor_accesses=[TensorAccess(name='I', projection={'N': 'n', 'C': 'c', 'H': 'p+r', 'W': 'q+s'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=8), TensorAccess(name='F', projection={'M': 'm', 'C': 'c', 'R': 'r', 'S': 's'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=8), TensorAccess(name='O', projection={'N': 'n', 'M': 'm', 'P': 'p', 'Q': 'q'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=8)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1)], iteration_space_shape={}, rank_sizes={'M': 128, 'C': 64, 'N': 1, 'P': 24, 'Q': 24, 'R': 3, 'S': 3}, n_instances=1, bits_per_value={}, persistent_tensors=None)

# %%
def conv_ops(input_shape: dict[str, int], filter_shape: dict[str, int]) -> int:
    """
    Calculates the amount of multiplications in a convolutional layer.

    Parameters
    ----------
    input_shape:
            Input shape, which has keys "N", "C", "H", "W".
    filter_shape:
            Filter weight shape, which has keys "M", "C", "R", "S".

    Returns
    -------
    The number of multiplications in the convolution.
    """
    # Rank shapes
    N = input_shape["N"]
    H = input_shape["H"]
    W = input_shape["W"]
    R = filter_shape["R"]
    S = filter_shape["S"]
    P: int = (H - R) + 1
    Q: int = (W - S) + 1
    C = filter_shape["C"]
    M = filter_shape["M"]

    # raise NotImplementedError("conv_ops is not implemented.")
    ########################
    #### YOUR CODE HERE ####
    ########################
    return N * M * P * Q * C * R * S


def min_conv_data_movement(
    input_shape: dict[str, int],
    filter_shape: dict[str, int],
) -> int:
    """
    Return the total number of reads and writes from/to off-chip memory (in
    number of tensor elements) assuming each tensor is only read/written once.

    In your implementation, consider only reads of tensors I, F, and writes of tensor O.

    Parameters
    ----------
    input_shape:
            Dictionary of the size of each rank of the input.
    filter_shape:
            Dictionary of the size of each rank of the filter.
    """
    # Rank shapes
    N = input_shape["N"]
    H = input_shape["H"]
    W = input_shape["W"]
    R = filter_shape["R"]
    S = filter_shape["S"]
    P = (H - R) + 1
    Q = (W - S) + 1
    C = filter_shape["C"]
    M = filter_shape["M"]

    ########################
    #### YOUR CODE HERE ####
    ########################
    # raise NotImplementedError("please complete the rest of the function")
    return N*C*H*W + C*M*R*S + N*M*P*Q

def roofline_transition(
    peak_computational_throughput: Number, bandwidth: Number
) -> Number:
    """
    Return the computational intensity (in ops/tensor-element) when the
    processing turns from bandwidth- to compute-bound.

    Parameters
    ----------
    peak_computational_throughput:
        Peak computational throughput in ops/cycle
    bandwidth:
        Memory bandwidth in tensor-element/cycle
    """
    # raise NotImplementedError("not implemented")
    ########################
    #### YOUR CODE HERE ####
    ########################
    return peak_computational_throughput/bandwidth

# %%
# Assume a convolutional layer with the following shape
# input_shape = {"N": 4, "C": 64, "H": 24, "W": 24}

# filter_shape = {"C": 64, "M": 128, "R": 3, "S": 3}

# throughput = 8*1024 # 8,192 ops/cycle
# bandwidth = 25      # 25 tensor-element/cycle

# computational_intensities = []
# actual_throughputs = []
# for N in [1, 2, 4, 8, 16, 32]:
#     input_shape["N"] = N
#     spec = af.Spec.from_yaml(
#         "./specs/conv.workload.yaml",
#         "./specs/simple.arch.yaml",
#         jinja_parse_data={"N": N}
#     )
#     spec.mapper.metrics = Metrics.LATENCY
#     mapping_result = af.mapper.FFM.map_workload_to_arch(spec)
#     num_conv_ops = conv_ops(input_shape, filter_shape) # TODO implement...
#     latency = mapping_result["Total<SEP>latency"].min()*1e9
#     actual_throughput = num_conv_ops/latency
#     actual_throughputs.append(actual_throughput)
#     data_movement = min_conv_data_movement(input_shape, filter_shape)
#     computational_intensity = num_conv_ops/data_movement
#     computational_intensities.append(computational_intensity)

# import matplotlib.pyplot as plt

# fig, ax = plt.subplots()

# ax.scatter(computational_intensities, actual_throughputs)

# MIN_CI = 200
# MAX_CI = 380
# ax.plot(
#     [MIN_CI, roofline_transition(throughput, bandwidth)],
#     [MIN_CI*bandwidth, throughput],
#     label="Bandwidth-bound"
# )
# ax.plot(
#     [roofline_transition(throughput, bandwidth), MAX_CI],
#     [throughput, throughput],
#     label="Compute-bound"
# )
# ax.set_xlabel("Computational intensity (ops/tensor-element)")
# ax.set_ylabel("Actual computational throughput (ops/cycle)")
# ax.legend()

# %% [markdown]
# ### Part 1: RAG workload

# %%
with open("./specs/gpt175B.yaml") as f:
	# print(f.read())
    print("opened")
# Out:
# opened

# %%
spec = af.Spec.from_yaml(
    "./specs/gpt175B.yaml",
    jinja_parse_data={}
)
# spec.workload
rank_sizes = spec.workload.rank_sizes

# %%
spec = af.Spec.from_yaml(
    "./specs/rag.yaml",
    jinja_parse_data={}
)

rank_sizes = spec.workload.rank_sizes
for einsum in spec.workload.einsums:
    # get all ranks involved in this einsum
    ranks = einsum.ranks  # or .rank_set, .dimensions — check via print(dir(einsum))
    complexity = 1
    for r in ranks:
        complexity *= rank_sizes[r]
    print(f"{einsum.name}: {complexity} ops  (ranks: {ranks})")
# Out:
# X: 12582912000 ops  (ranks: oset({'D', 'T', 'V'}))
# Q: 301989888 ops  (ranks: oset({'D', 'DK', 'T'}))
# K: 301989888 ops  (ranks: oset({'D', 'DK', 'T'}))
# V: 301989888 ops  (ranks: oset({'D', 'DV', 'T'}))
# A: 201326592 ops  (ranks: oset({'DK', 'S', 'T'}))
# P: 262144 ops  (ranks: oset({'S', 'T'}))
# H: 201326592 ops  (ranks: oset({'DV', 'S', 'T'}))
# Z_Q: 393216 ops  (ranks: oset({'DV', 'T'}))
# S_score: 786432 ops  (ranks: oset({'DV', 'N'}))
# TK: 524288 ops  (ranks: oset({'N', 'T'}))

# %%
spec = af.Spec.from_yaml(
    "./specs/bert_rag.yaml",
    jinja_parse_data={}
)
spec.workload
# Out:
# Workload(einsums=[Einsum(name='I', tensor_accesses=[TensorAccess(name='I_in', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='I', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=True, renames=[], n_instances=1), Einsum(name='V', tensor_accesses=[TensorAccess(name='I', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='WV', projection={'H': 'h', 'E': 'e', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='V', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'E': 'e'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='K', tensor_accesses=[TensorAccess(name='I', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='WK', projection={'H': 'h', 'E': 'e', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='K', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'E': 'e'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='Q', tensor_accesses=[TensorAccess(name='I', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='WQ', projection={'H': 'h', 'E': 'e', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='Q', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'E': 'e'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='QK', tensor_accesses=[TensorAccess(name='Q', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'E': 'e'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='K', projection={'BB': 'bb', 'M': 'p', 'H': 'h', 'E': 'e'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='QK', projection={'BB': 'bb', 'M': 'm', 'P': 'p', 'H': 'h'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[Rename(name='input', source='Q', expected_count=None)], n_instances=1), Einsum(name='QK_softmax', tensor_accesses=[TensorAccess(name='QK', projection={'BB': 'bb', 'M': 'm', 'P': 'p', 'H': 'h'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='QK_softmax', projection={'BB': 'bb', 'M': 'm', 'P': 'p', 'H': 'h'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='AV', tensor_accesses=[TensorAccess(name='QK_softmax', projection={'BB': 'bb', 'M': 'm', 'P': 'p', 'H': 'h'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='V', projection={'BB': 'bb', 'M': 'p', 'H': 'h', 'E': 'f'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='AV', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'F': 'f'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=F ...

# %%
spec = af.Spec.from_yaml(
    "./specs/full.yaml",
    jinja_parse_data={}
)
spec.workload
# Out:
# Workload(einsums=[Einsum(name='I', tensor_accesses=[TensorAccess(name='I_in', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='I', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=True, renames=[], n_instances=1), Einsum(name='V', tensor_accesses=[TensorAccess(name='I', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='WV', projection={'H': 'h', 'E': 'e', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='V', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'E': 'e'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='K', tensor_accesses=[TensorAccess(name='I', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='WK', projection={'H': 'h', 'E': 'e', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='K', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'E': 'e'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='Q', tensor_accesses=[TensorAccess(name='I', projection={'BB': 'bb', 'M': 'm', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='WQ', projection={'H': 'h', 'E': 'e', 'D': 'd'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='Q', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'E': 'e'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='QK', tensor_accesses=[TensorAccess(name='Q', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'E': 'e'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='K', projection={'BB': 'bb', 'M': 'p', 'H': 'h', 'E': 'e'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='QK', projection={'BB': 'bb', 'M': 'm', 'P': 'p', 'H': 'h'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='QK_softmax', tensor_accesses=[TensorAccess(name='QK', projection={'BB': 'bb', 'M': 'm', 'P': 'p', 'H': 'h'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='QK_softmax', projection={'BB': 'bb', 'M': 'm', 'P': 'p', 'H': 'h'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='AV', tensor_accesses=[TensorAccess(name='QK_softmax', projection={'BB': 'bb', 'M': 'm', 'P': 'p', 'H': 'h'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='V', projection={'BB': 'bb', 'M': 'p', 'H': 'h', 'E': 'f'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='AV', projection={'BB': 'bb', 'M': 'm', 'H': 'h', 'F': 'f'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='Z', te ...

# %%
print("TODO")
# Out:
# TODO

# %% [markdown]
# ### Part 2: Analysis
# Analyze the mappings and energy breakdown, and report energy or latency bottlenecks.
# Which architectural components are bottlenecks? For which workload configurations?
# Which Einsums in the workload cause these bottlenecks?

# %%
spec = af.Spec.from_yaml(
    "specs/basic8.yaml",
    "specs/gpt175B.yaml",
    jinja_parse_data={}
)
spec.arch
# Out:
# Arch(nodes=ArchNodes([Memory(name='Disk', spatial=[], component_class=None, component_model=None, component_modeling_log=[], actions=[TensorHolderAction(name='read', energy=0, energy_scale=1, latency='1 / (7e9 * 8)', latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action='1 if bits_per_action is None else bits_per_action'), TensorHolderAction(name='write', energy=0, energy_scale=1, latency='1 / (7e9 * 8)', latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action='1 if bits_per_action is None else bits_per_action')], enabled=True, area=0, total_area=None, area_scale=1, leak_power=0, total_leak_power=None, leak_power_scale=1, energy_scale=1, total_latency='sum(*action2latency.values())', latency_scale=1, n_parallel_instances=1, extra_attributes_for_component_model=_ExtraAttrs(), tensors=Tensors(keep='~Intermediates', may_keep='All', back='Nothing', tile_shape=[], no_refetch_from_above='~All', no_resend_to_below='~All', tensor_order_options=[], force_memory_hierarchy_order=True), bits_per_value_scale={'All': 1}, bits_per_action=None, size='inf', skip_initial_output_write=True), Memory(name='MainMemory', spatial=[], component_class=None, component_model=None, component_modeling_log=[], actions=[TensorHolderAction(name='read', energy=7.03e-12, energy_scale=1, latency='1 / (68e9 * 8)', latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action='1 if bits_per_action is None else bits_per_action'), TensorHolderAction(name='write', energy=7.03e-12, energy_scale=1, latency='1 / (68e9 * 8)', latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action='1 if bits_per_action is None else bits_per_action')], enabled=True, area=0, total_area=None, area_scale=1, leak_power=0, total_leak_power=None, leak_power_scale=1, energy_scale=1, total_latency='sum(*action2latency.values())', latency_scale=1, n_parallel_instances=1, extra_attributes_for_component_model=_ExtraAttrs(), tensors=Tensors(keep='~Intermediates', may_keep='All', back='Nothing', tile_shape=[], no_refetch_from_above='~All', no_resend_to_below='~All', tensor_order_options=[], force_memory_hierarchy_order=True), bits_per_value_scale={'All': 1}, bits_per_action=None, size='8*1024*1024*1024*8', skip_initial_output_write=True), Memory(name='OnChipSRAM', spatial=[], component_class=None, component_model=None, component_modeling_log=[], actions=[TensorHolderAction(name='read', energy=2.49e-13, energy_scale=1, latency='1 / (512e9 * 8)', latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action='1 if bits_per_action is None else bits_per_action'), TensorHolderAction(name='write', energy=2.93e-13, energy_scale=1, latency='1 / (128e9 * 8)', latency_scale=1, extra_attributes_for_component_model=EvalExtras(), bits_per_action='1 if bits_per_action is None else bits_per_action')], enabled=True, area=8e-06, total_area=None, area_scale=1, leak_power=0, total_leak_power=None, leak_power_scale=1, energy_scale=1, total_latency='max(read_latency, write_latency)', latency_scale=1, n_parallel_instances=1, extra_attributes_for_component_model=_ExtraAttrs(), tensors=Tensors(keep='All', may_keep='<Nothing if keep is defined, else All>', back='Nothing', tile_shape=[], no_refetch_from_above='~All', no_resend_to_below='~All', tensor_order_options=[], force_memory_hierarchy_order=True), bits_per_value_scale={'All': 1}, bits_per_action=None, size='8*1024*1024*8', skip_initial_output_write=True), Compute(name='MAC', spatial=[], component_class=None, component_model=None, component_modeling_log=[], actions=[Action(name='compute', energy=8.4e-14, energy_scale=1, latency='1 / (1e9)', latency_scale=1, extra_attributes_for_component_model=EvalExtras())], enabled='len(All) == 3', area=9e-11, total_area=None, area_scale=1, leak_power=0, total_leak_power=None, leak_power_scale=1, energy_scale=1, total_latency='sum(*action2latency.values())', latency_scale=1, n_parallel_instances=1, extra_attri ...

# %%
if spec.workload:
    print("ok")
# Out:
# ok

# %%
# mappings = spec.map_workload_to_arch()
pass

# %%
mappings.energy(per_component=True, per_action=True)

# %%
mappings.latency(per_component=True)

# %%
spec.mapper.metrics = Metrics.LATENCY | Metrics.ENERGY
area = spec.calculate_component_area_energy_latency_leak().arch.total_area
print("Your area is", area) 

mappings = spec.map_workload_to_arch()
edp = (mappings.data["Total<SEP>energy"], mappings.data["Total<SEP>latency"])
print(edp)

# %%
WORKLOAD_PATH = "specs/full.yaml",

workload = af.Workload.from_yaml(
    WORKLOAD_PATH,
    top_key='workload',
    jinja_parse_data={},
)
# renames = af.Renames.from_yaml(
#     WORKLOAD_PATH,
#     top_key='renames',
#     jinja_parse_data={},
# )

print(f'Loaded {len(workload.einsums)} einsums:')
for e in workload.einsums:
    print(f'  {e.name}')
# Out:
# Loaded 25 einsums:
#   I
#   V
#   K
#   Q
#   QK
#   QK_softmax
#   AV
#   Z
#   FFA
#   FFB
#   CLS
#   SIM
#   TK
#   TK_flat
#   II_in
#   II
#   VV
#   KK
#   QQ
#   QQKK
#   QQKK_softmax
#   AAV
#   ZZ
#   FFFA
#   FFFB

# %%
spec = af.Spec.from_yaml(
    "./workload/full_EdgeRAG.yaml",
    jinja_parse_data={}
)
print("ok")
spec.workload
# Out:
# ok
# Workload(einsums=[Einsum(name='enc_input', tensor_accesses=[TensorAccess(name='enc_input_raw', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_HIDDEN': 'enc_hidden'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='enc_input', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_HIDDEN': 'enc_hidden'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=True, renames=[], n_instances=1), Einsum(name='enc_queries', tensor_accesses=[TensorAccess(name='enc_input', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_HIDDEN': 'enc_hidden'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='enc_W_query', projection={'ENC_NUM_HEADS': 'enc_num_heads', 'ENC_HEAD_DIM': 'enc_head_dim', 'ENC_HIDDEN': 'enc_hidden'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='enc_queries', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_NUM_HEADS': 'enc_num_heads', 'ENC_HEAD_DIM': 'enc_head_dim'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='enc_keys', tensor_accesses=[TensorAccess(name='enc_input', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_HIDDEN': 'enc_hidden'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='enc_W_key', projection={'ENC_NUM_HEADS': 'enc_num_heads', 'ENC_HEAD_DIM': 'enc_head_dim', 'ENC_HIDDEN': 'enc_hidden'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='enc_keys', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_NUM_HEADS': 'enc_num_heads', 'ENC_HEAD_DIM': 'enc_head_dim'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='enc_values', tensor_accesses=[TensorAccess(name='enc_input', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_HIDDEN': 'enc_hidden'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='enc_W_value', projection={'ENC_NUM_HEADS': 'enc_num_heads', 'ENC_HEAD_DIM': 'enc_head_dim', 'ENC_HIDDEN': 'enc_hidden'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='enc_values', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_NUM_HEADS': 'enc_num_heads', 'ENC_HEAD_DIM': 'enc_head_dim'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='enc_attn_scores', tensor_accesses=[TensorAccess(name='enc_queries', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_NUM_HEADS': 'enc_num_heads', 'ENC_HEAD_DIM': 'enc_head_dim'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='enc_keys', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_kv_pos', 'ENC_NUM_HEADS': 'enc_num_heads', 'ENC_HEAD_DIM': 'enc_head_dim'}, output=False, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None), TensorAccess(name='enc_attn_scores', projection={'BATCH': 'batch', 'ENC_SEQ_LEN': 'enc_seq_len', 'ENC_KV_POS': 'enc_kv_pos', 'ENC_NUM_HEADS': 'enc_num_heads'}, output=True, persistent=False, backing_storage_size_scale=1.0, bits_per_value=None)], iteration_space_shape=[], rank_sizes={}, is_copy_operation=False, renames=[], n_instances=1), Einsum(name='enc_attn_weights', tensor_accesses=[TensorAccess(name='enc_attn_scores', projection={'BATCH': 'batch', ' ...
